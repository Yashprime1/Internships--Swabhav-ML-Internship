# %%
import pandas as pd
import numpy as np

# %%
marks=pd.read_csv('marks_frame.csv')

# %%
marks
# Out:
#          Saurav    Java    90
# 0       Harshit  Python  95.0
# 1       Vaibhav    Java  80.0
# 2        Nitesh       C  90.0
# 3      Kartikey    HTML  98.0
# 4         Kunal    Java  60.0
# 5  Venkateshwar  Python  70.0
# 6        Akshay  Python   NaN
# 7       Ratnesh     NaN  60.0

# %%
marks=pd.read_csv('marks_frame.csv',header=None,)

# %%
marks.columns=['Name','Language','Marks']

# %%
marks
# Out:
#            Name Language  Marks
# 0        Saurav     Java   90.0
# 1       Harshit   Python   95.0
# 2       Vaibhav     Java   80.0
# 3        Nitesh        C   90.0
# 4      Kartikey     HTML   98.0
# 5         Kunal     Java   60.0
# 6  Venkateshwar   Python   70.0
# 7        Akshay   Python    NaN
# 8       Ratnesh      NaN   60.0

# %%
df=marks

# %%
df.index
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
df['Marks'].dtype
# Out:
# dtype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      9 non-null      object
#  1   Language  8 non-null      object
#  2   Marks     8 non-null      float64
# dtypes: float64(1), object(2)
# memory usage: 344.0+ bytes

# %%
df.isnull().any()
# Out:
# Name        False
# Language     True
# Marks        True
# dtype: bool

# %%
df.describe()
# Out:
#          Marks
# count   8.0000
# mean   80.3750
# std    15.3431
# min    60.0000
# 25%    67.5000
# 50%    85.0000
# 75%    91.2500
# max    98.0000

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
type(df[['Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['Name','Marks']])
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # slicing

# %%
df[0:2]
# Out:
#       Name Language  Marks
# 0   Saurav     Java   90.0
# 1  Harshit   Python   95.0

# %%
df.iloc[0:2]
# Out:
#       Name Language  Marks
# 0   Saurav     Java   90.0
# 1  Harshit   Python   95.0

# %%
df.loc[:4,:'Language']  #inclusive
# Out:
#        Name Language
# 0    Saurav     Java
# 1   Harshit   Python
# 2   Vaibhav     Java
# 3    Nitesh        C
# 4  Kartikey     HTML

# %%
df.loc[[3,6],['Name','Language']]
# Out:
#            Name Language
# 3        Nitesh        C
# 6  Venkateshwar   Python

# %%
df[df['Marks']>50]
# Out:
#            Name Language  Marks
# 0        Saurav     Java   90.0
# 1       Harshit   Python   95.0
# 2       Vaibhav     Java   80.0
# 3        Nitesh        C   90.0
# 4      Kartikey     HTML   98.0
# 5         Kunal     Java   60.0
# 6  Venkateshwar   Python   70.0
# 8       Ratnesh      NaN   60.0

# %%
df['Language'].value_counts()
# Out:
# Python    3
# Java      3
# C         1
# HTML      1
# Name: Language, dtype: int64

# %% [markdown]
# ## Read json

# %%
df2=pd.read_json('https://restcountries.eu/rest/v2/all')

# %%
df2
# Out:
#                   name topLevelDomain alpha2Code alpha3Code callingCodes  \
# 0          Afghanistan          [.af]         AF        AFG         [93]
# 1        Åland Islands          [.ax]         AX        ALA        [358]
# 2              Albania          [.al]         AL        ALB        [355]
# 3              Algeria          [.dz]         DZ        DZA        [213]
# 4       American Samoa          [.as]         AS        ASM       [1684]
# ..                 ...            ...        ...        ...          ...
# 245  Wallis and Futuna          [.wf]         WF        WLF        [681]
# 246     Western Sahara          [.eh]         EH        ESH        [212]
# 247              Yemen          [.ye]         YE        YEM        [967]
# 248             Zambia          [.zm]         ZM        ZMB        [260]
# 249           Zimbabwe          [.zw]         ZW        ZWE        [263]
#
#        capital                                       altSpellings   region  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            250 non-null    object
#  1   topLevelDomain  250 non-null    object
#  2   alpha2Code      250 non-null    object
#  3   alpha3Code      250 non-null    object
#  4   callingCodes    250 non-null    object
#  5   capital         250 non-null    object
#  6   altSpellings    250 non-null    object
#  7   region          250 non-null    object
#  8   subregion       250 non-null    object
#  9   population      250 non-null    int64
#  10  latlng          250 non-null    object
#  11  demonym         250 non-null    object
#  12  area            240 non-null    float64
#  13  gini            153 non-null    float64
#  14  timezones       250 non-null    object
#  15  borders         250 non-null    object
#  16  nativeName      250 non-null    object
# ...

# %%
df2.isna().any()
# Out:
# name              False
# topLevelDomain    False
# alpha2Code        False
# alpha3Code        False
# callingCodes      False
# capital           False
# altSpellings      False
# region            False
# subregion         False
# population        False
# latlng            False
# demonym           False
# area               True
# gini               True
# timezones         False
# borders           False
# nativeName        False
# numericCode        True
# currencies        False
# languages         False
# translations      False
# flag              False
# regionalBlocs     False
# cioc               True
# dtype: bool

# %%
df2[df2['name']=='India']
# Out:
#       name topLevelDomain alpha2Code alpha3Code callingCodes    capital  \
# 104  India          [.in]         IN        IND         [91]  New Delhi
#
#                                          altSpellings region      subregion  \
# 104  [IN, Bhārat, Republic of India, Bharat Ganrajya]   Asia  Southern Asia
#
#      population  ...    timezones                                   borders  \
# 104  1295210000  ...  [UTC+05:30]  [AFG, BGD, BTN, MMR, CHN, NPL, PAK, LKA]
#
#      nativeName  numericCode  \
# 104        भारत        356.0
#
#                                             currencies  \
# 104  [{'code': 'INR', 'name': 'Indian rupee', 'symb...
#
#                                              languages  \
# 104  [{'iso639_1': 'hi', 'iso639_2': 'hin', 'name':...
#
#                                           translations  \
# 104  {'de': 'Indien', 'es': 'India', 'fr': 'Inde', ...
#
#                                       flag  \
# 104  https://restcountries.eu/data/ind.svg
#
# ...

# %%
df2.iloc[104]
# Out:
# name                                                          India
# topLevelDomain                                                [.in]
# alpha2Code                                                       IN
# alpha3Code                                                      IND
# callingCodes                                                   [91]
# capital                                                   New Delhi
# altSpellings       [IN, Bhārat, Republic of India, Bharat Ganrajya]
# region                                                         Asia
# subregion                                             Southern Asia
# population                                               1295210000
# latlng                                                 [20.0, 77.0]
# demonym                                                      Indian
# area                                                    3.28759e+06
# gini                                                           33.4
# ...
