# %% [markdown]
# # Markdown

# %% [markdown]
# ## Swabhav Tech~~Labs~~

# %% [markdown]
# one
# two
# three

# %% [raw]
# def fun:
#     print("some")
# def not_sure:
#     print('abc')

# %% [markdown]
# ![deathnote](data:image/jpeg;base64,...)
