# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
tips=sns.load_dataset('tips')
flights=sns.load_dataset('flights')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Scatter and Line Plots

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',size='smoker',data=tips)

# %%
sns.lineplot(x='month',y='passengers',data=flights,estimator=sum)

# %%
sns.lineplot(x='month',y='passengers',ci=False,data=flights,estimator=sum)

# %%
sns.lineplot(x='month',y='passengers',ci=False,data=flights,estimator=sum)
plt.gcf().set_size_inches(10,5)

# %%
sns.lineplot(x='year',y='passengers',ci=False,data=flights,estimator=sum)
plt.gcf().set_size_inches(10,5)

# %% [markdown]
# ## Relplots

# %%
sns.relplot(x='total_bill',hue='smoker',y='tip',data=tips,col='sex',size='time')

# %% [markdown]
# ## Regplots

# %%
sns.regplot(x='total_bill',y='tip',data=tips)

# %%
sns.regplot(x='total_bill',y='tip',data=tips,ci=False)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,ci=False)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,ci=False,hue='smoker',col='day')

# %%
sns.residplot(x='total_bill',y='tip',data=tips)

# %% [markdown]
# ## Heatmap

# %%
fgrp=flights.pivot('month','year','passengers')
fgrp
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(fgrp)

# %%
cmat=tips.corr()
cmat
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(cmat)

# %%
sns.heatmap(cmat,annot=True)

# %%
tips['is_smoker']=tips['smoker'].apply(lambda v:1 if v=='Yes' else 0)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size is_smoker
# 0         16.99  1.01  Female     No   Sun  Dinner     2         0
# 1         10.34  1.66    Male     No   Sun  Dinner     3         0
# 2         21.01  3.50    Male     No   Sun  Dinner     3         0
# 3         23.68  3.31    Male     No   Sun  Dinner     2         0
# 4         24.59  3.61  Female     No   Sun  Dinner     4         0
# ..          ...   ...     ...    ...   ...     ...   ...       ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         1
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1
# 242       17.82  1.75    Male     No   Sat  Dinner     2         0
# 243       18.78  3.00  Female     No  Thur  Dinner     2         0
#
# [244 rows x 8 columns]

# %%
k=tips.corr()
k
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
tips.is_smoker=tips.is_smoker.astype('int32')

# %%
k=tips.corr()
k
# Out:
#             total_bill       tip      size  is_smoker
# total_bill    1.000000  0.675734  0.598315   0.085721
# tip           0.675734  1.000000  0.489299   0.005929
# size          0.598315  0.489299  1.000000  -0.133178
# is_smoker     0.085721  0.005929 -0.133178   1.000000

# %%
sns.heatmap(k)
