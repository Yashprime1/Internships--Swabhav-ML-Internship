# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
plt.isinteractive()
# Out:
# True

# %%
df=sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
daywise_bill=df.groupby(by='day',as_index=False)['total_bill'].sum()

# %%
daywise_bill
# Out:
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %%
plt.style.use('seaborn')

# %%
plt.pie(daywise_bill['total_bill'],labels=daywise_bill['day'],autopct="%.2f",explode=(0,0,0,0.2))
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3a844fd050>,
# ...
#  [Text(0.8317418198604141, 0.7198649492059511, 'Thur'),
#   Text(-0.07485481766878774, 1.0974501156188252, 'Fri'),
#   Text(-1.0902316372510155, 0.1462702195833805, 'Sat'),
#   Text(0.6368397984556922, -1.1333291980280547, 'Sun')],
#  [Text(0.4536773562874985, 0.3926536086577915, '22.71'),
#   Text(-0.04082990054661149, 0.5986091539739046, '6.75'),
#   Text(-0.5946718021369175, 0.07978375613638934, '36.84'),
#   Text(0.39190141443427207, -0.6974333526326489, '33.70')])

# %% [markdown]
#  bar graph and line graph
#
#  time series like sales data

# %%
plt.plot(daywise_bill['day'],daywise_bill['total_bill'])
plt.title('Daywise sales')
plt.xlabel('Days')
plt.ylabel('Total_bill')
# Out:
# Text(0, 0.5, 'Total_bill')

# %%
plt.figure(figsize=(10,5))
plt.bar(daywise_bill['day'],daywise_bill['total_bill'])
plt.title('Daywise sales')
plt.xlabel('Days')
plt.ylabel('Total_bill')
# Out:
# Text(0, 0.5, 'Total_bill')

# %%
plt.scatter(df['day'],df['total_bill'])

# %%
plt.scatter(df['tip'],df['total_bill'])

# %% [markdown]
# # objects api

# %%
ax=plt.subplot()
ax.bar(daywise_bill['day'],daywise_bill['total_bill'])
ax.set_title('Daywise sales')
ax.set_xlabel('Days')
ax.set_ylabel('Total_bill')
# Out:
# Text(0, 0.5, 'Total_bill')

# %%
fig,ax=plt.subplots(1,2)
fig.suptitle('Daywise sales')
ax[0].bar(daywise_bill['day'],daywise_bill['total_bill'])
ax[0].set_title('Daywise sales')
ax[0].set_xlabel('Days')
ax[0].set_ylabel('Total_bill')
ax[1].pie(daywise_bill['total_bill'],labels= daywise_bill['day'],)

ax[1].set_xlabel('Days')
ax[1].set_ylabel('Total_bill')
# Out:
# Text(0, 0.5, 'Total_bill')

# %%
df=sns.load_dataset('tips')

# %%
df['time']
# Out:
# 0      Dinner
# 1      Dinner
# 2      Dinner
# 3      Dinner
# 4      Dinner
#         ...
# 239    Dinner
# 240    Dinner
# 241    Dinner
# 242    Dinner
# 243    Dinner
# Name: time, Length: 244, dtype: category
# Categories (2, object): [Lunch, Dinner]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-e67c12251e95> in <module>
# ----> 1 df=pd.read
#
# ~/Desktop/codersground/anaconda3/lib/python3.7/site-packages/pandas/__init__.py in __getattr__(name)
#     260             return _SparseArray
#     261
# --> 262         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     263
#     264
#
# AttributeError: module 'pandas' has no attribute 'read'
