# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import misc

# %%
racoon=misc.face()

# %%
racoon.shape,racoon.size
# Out:
# ((768, 1024, 3), 2359296)

# %%
plt.imshow(racoon)

# %%
racoon[767,0]
# Out:
# array([ 85, 101,  74], dtype=uint8)

# %%
rsl=racoon[20:500,400:900]

# %%
plt.imshow(rsl)

# %%
rsl2=rsl.copy()
rsl2.shape
# Out:
# (480, 500, 3)

# %%
rsl2[:,:,0:2]=0

# %%
plt.imshow(rsl2)

# %%
import matplotlib.image as im
