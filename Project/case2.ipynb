# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_excel('Analysis Data 1.xlsx')

# %%
df
# Out:
#       Sr. No.         Date Exhibition Id  Visitor Id         Products  \
# 0           1  25/Dec/2019      KOL12019  KOL1941617      Accessories
# 1           2  25/Dec/2019      KOL12019  KOL1932365      Accessories
# 2           3  19/Dec/2019      KOL12019  KOL1951287      Accessories
# 3           4  18/Dec/2019      KOL12019  KOL1982621      Accessories
# 4           5  18/Dec/2019      KOL12019  KOL1808748      Accessories
# ...       ...          ...           ...         ...              ...
# 2634     2635  22/Dec/2019      KOL12019  KOL1965123  Wooden Products
# 2635     2636  25/Dec/2019      KOL12019  KOL1924811     Turkish Lamp
# 2636     2637  22/Dec/2019      KOL12019  KOL1927587     Turkish Lamp
# 2637     2638  16/Dec/2019      KOL12019  KOL1824228     Turkish Lamp
# 2638     2639  14/Dec/2019      KOL12019  KOL1931253     Turkish Lamp
#
#      Payment Mode  Amount
# 0            Cash    1350
# 1            Cash   75000
# 2            Cash    1000
# ...

# %%
df.describe(include='all')
# Out:
#             Sr. No.         Date Exhibition Id  Visitor Id Products  \
# count   2639.000000         2639          2639        2639     2639
# unique          NaN           13             1        1698      133
# top             NaN  25/Dec/2019      KOL12019  KOL1832746    Suits
# freq            NaN          377          2639          20      413
# mean    1320.000000          NaN           NaN         NaN      NaN
# std      761.958004          NaN           NaN         NaN      NaN
# min        1.000000          NaN           NaN         NaN      NaN
# 25%      660.500000          NaN           NaN         NaN      NaN
# 50%     1320.000000          NaN           NaN         NaN      NaN
# 75%     1979.500000          NaN           NaN         NaN      NaN
# max     2639.000000          NaN           NaN         NaN      NaN
#
#        Payment Mode         Amount
# count          2639    2639.000000
# unique            4            NaN
# top            Cash            NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2639 entries, 0 to 2638
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sr. No.        2639 non-null   int64
#  1   Date           2639 non-null   object
#  2   Exhibition Id  2639 non-null   object
#  3   Visitor Id     2639 non-null   object
#  4   Products       2639 non-null   object
#  5   Payment Mode   2639 non-null   object
#  6   Amount         2639 non-null   int64
# dtypes: int64(2), object(5)
# memory usage: 144.4+ KB

# %%
len(df['Products'].unique())
# Out:
# 133

# %%
len(df['Date'].unique())
# Out:
# 13

# %%
df_products = df.groupby(by=['Products','Date'], as_index=False).agg({'Sr. No.': pd.Series.nunique})

# %%
df_products
# Out:
#             Products         Date  Sr. No.
# 0        Accessories  18/Dec/2019        3
# 1        Accessories  19/Dec/2019        1
# 2        Accessories  25/Dec/2019        2
# 3         Air Cooler  14/Dec/2019        2
# 4         Air Cooler  15/Dec/2019        3
# ..               ...          ...      ...
# 651  textile product  24/Dec/2019        1
# 652  textile product  25/Dec/2019        3
# 653     wall hanging  14/Dec/2019        1
# 654     wall hanging  17/Dec/2019        2
# 655     wall hanging  19/Dec/2019        1
#
# [656 rows x 3 columns]

# %%
dates=df_products['Date'].unique()
dates=sorted(dates)
print(dates)
# Out:
# ['13/Dec/2019', '14/Dec/2019', '15/Dec/2019', '16/Dec/2019', '17/Dec/2019', '18/Dec/2019', '19/Dec/2019', '20/Dec/2019', '21/Dec/2019', '22/Dec/2019', '23/Dec/2019', '24/Dec/2019', '25/Dec/2019']

# %%
d={}
for date in dates:
    d[date]=df_products[df_products['Date']==date]

# %%
for date in dates:
    print('********************************************************************************************************************************')
    print(date)
    print('********************************************************************************************************************************')
    print(d[date])
    print(type(d[date]))
    print('********************************************************************************************************************************')
# Out:
# ********************************************************************************************************************************
# 13/Dec/2019
# ********************************************************************************************************************************
#                      Products         Date  Sr. No.
# 19                        Bag  13/Dec/2019        2
# 33                   Bedsheet  13/Dec/2019        2
# 42                       Belt  13/Dec/2019        1
# 51                   Body oil  13/Dec/2019        1
# 58                     Carpet  13/Dec/2019        2
# 82                     Cloths  13/Dec/2019        4
# 88                  Cosmetics  13/Dec/2019        1
# 93                Cotton/Silk  13/Dec/2019        1
# 100                  Crockery  13/Dec/2019        1
# 117                 Dry Fruit  13/Dec/2019        4
# 133            Electric Chair  13/Dec/2019        2
# 144              Etthnic Wear  13/Dec/2019        2
# ...

# %%
# changing column names

# %%
for date in dates:
    d[date].columns=['Products','Date','Count']

# %% [markdown]
# ## Checking Normal Distribution through mean and median

# %%
for date in dates:
    print('********************************************************************************************************************************')
    print(date)
    print('********************************************************************************************************************************')

    print('********************************************************************************************************************************')
# Out:
# ********************************************************************************************************************************
# 13/Dec/2019
# ********************************************************************************************************************************
# ********************************************************************************************************************************
# ********************************************************************************************************************************
# 14/Dec/2019
# ********************************************************************************************************************************
# ********************************************************************************************************************************
# ********************************************************************************************************************************
# 15/Dec/2019
# ...

# %% [markdown]
# ## Analyzing each date seperately

# %%
## date 1   ##--- assumption -- all product names will be shown by indices  (since there are many products to be shown or overlap of names would occur in x-axis)-- ##

# %%
d[dates[0]]=d[dates[0]].sort_values(by='Count',ascending=False)
b=sns.barplot(x='Products',y='Count',data=d[dates[0]])
plt.gcf().set_size_inches(50,15)
b.axes.set_title(dates[0],fontsize=50)
b.set_xlabel('Products',fontsize=30)
b.set_ylabel('Count',fontsize=30)
_, ylabels = plt.yticks()
_, xlabels = plt.xticks()
print(ylabels[0])
print(xlabels[0])
b.set_yticklabels(b.get_yticks(), size=30)
b.set_xticklabels(b.get_xticks(), size=30)
# Out:
# Text(0, 0, '')
# Text(0, 0, 'Garments')
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '12'),
#  Text(0, 0, '13'),
#  Text(0, 0, '14'),
#  Text(0, 0, '15'),
#  Text(0, 0, '16'),
#  Text(0, 0, '17'),
#  Text(0, 0, '18'),
#  Text(0, 0, '19'),
#  Text(0, 0, '20'),
#  Text(0, 0, '21'),
#  Text(0, 0, '22'),
#  Text(0, 0, '23'),
#  Text(0, 0, '24'),
#  Text(0, 0, '25'),
#  Text(0, 0, '26'),
#  Text(0, 0, '27'),
#  Text(0, 0, '28'),
#  Text(0, 0, '29'),
#  Text(0, 0, '30'),
#  Text(0, 0, '31'),
#  Text(0, 0, '32'),
#  Text(0, 0, '33'),
#  Text(0, 0, '34')]

# %%
print(d[dates[0]].iloc[0]['Products'],d[dates[0]].iloc[0]['Count'])
print(d[dates[0]].iloc[1]['Products'],d[dates[0]].iloc[1]['Count'])
print(d[dates[0]].iloc[2]['Products'],d[dates[0]].iloc[2]['Count'])
# Out:
# Garments 19
# Suits 18
# Massager 8

# %%
print('Mean : ',d[dates[0]]['Count'].mean())
print('Median : ',d[dates[0]]['Count'].median())
# Out:
# Mean :  3.2
# Median :  2.0

# %%
## date 2

# %%
d[dates[1]]=d[dates[1]].sort_values(by='Count',ascending=False)
b=sns.barplot(x='Products',y='Count',data=d[dates[1]])
plt.gcf().set_size_inches(70,15)
b.axes.set_title(dates[1],fontsize=50)
b.set_xlabel('Products',fontsize=30)
b.set_ylabel('Count',fontsize=30)
b.set_yticklabels(b.get_yticks(), size=30)
b.set_xticklabels(b.get_xticks(), size=30)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '12'),
#  Text(0, 0, '13'),
#  Text(0, 0, '14'),
#  Text(0, 0, '15'),
#  Text(0, 0, '16'),
#  Text(0, 0, '17'),
#  Text(0, 0, '18'),
#  Text(0, 0, '19'),
#  Text(0, 0, '20'),
#  Text(0, 0, '21'),
#  Text(0, 0, '22'),
#  Text(0, 0, '23'),
#  Text(0, 0, '24'),
#  Text(0, 0, '25'),
#  Text(0, 0, '26'),
#  Text(0, 0, '27'),
#  Text(0, 0, '28'),
#  Text(0, 0, '29'),
#  Text(0, 0, '30'),
#  Text(0, 0, '31'),
#  Text(0, 0, '32'),
#  Text(0, 0, '33'),
#  Text(0, 0, '34'),
#  Text(0, 0, '35')]

# %%
print(d[dates[1]].iloc[0]['Products'],d[dates[1]].iloc[0]['Count'])
print(d[dates[1]].iloc[1]['Products'],d[dates[1]].iloc[1]['Count'])
print(d[dates[1]].iloc[2]['Products'],d[dates[1]].iloc[2]['Count'])
# Out:
# Suits 27
# Jamdani Saree 10
# Steam Irons 6

# %%
print('Mean : ',d[dates[1]]['Count'].mean())
print('Median : ',d[dates[1]]['Count'].median())
# Out:
# Mean :  2.8333333333333335
# Median :  1.5

# %%
## date 3

# %%
d[dates[2]]=d[dates[2]].sort_values(by='Count',ascending=False)
b=sns.barplot(x='Products',y='Count',data=d[dates[2]])
plt.gcf().set_size_inches(70,30)
b.axes.set_title(dates[2],fontsize=50)
b.set_xlabel('Products',fontsize=30)
b.set_ylabel('Count',fontsize=30)
b.set_yticklabels(b.get_yticks(), size=30)
b.set_xticklabels(b.get_xticks(), size=30)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '12'),
#  Text(0, 0, '13'),
#  Text(0, 0, '14'),
#  Text(0, 0, '15'),
#  Text(0, 0, '16'),
#  Text(0, 0, '17'),
#  Text(0, 0, '18'),
#  Text(0, 0, '19'),
#  Text(0, 0, '20'),
#  Text(0, 0, '21'),
#  Text(0, 0, '22'),
#  Text(0, 0, '23'),
#  Text(0, 0, '24'),
#  Text(0, 0, '25'),
#  Text(0, 0, '26'),
#  Text(0, 0, '27'),
#  Text(0, 0, '28'),
#  Text(0, 0, '29'),
#  Text(0, 0, '30'),
#  Text(0, 0, '31'),
#  Text(0, 0, '32'),
#  Text(0, 0, '33'),
#  Text(0, 0, '34'),
#  Text(0, 0, '35'),
#  Text(0, 0, '36'),
#  Text(0, 0, '37'),
#  Text(0, 0, '38'),
#  Text(0, 0, '39'),
#  Text(0, 0, '40'),
#  Text(0, 0, '41'),
#  Text(0, 0, '42'),
#  Text(0, 0, '43'),
#  Text(0, 0, '44'),
#  Text(0, 0, '45'),
#  Text(0, 0, '46'),
#  Text(0, 0, '47'),
# ...

# %%
print(d[dates[2]].iloc[0]['Products'],d[dates[2]].iloc[0]['Count'])
print(d[dates[2]].iloc[1]['Products'],d[dates[2]].iloc[1]['Count'])
print(d[dates[2]].iloc[2]['Products'],d[dates[2]].iloc[2]['Count'])
# Out:
# Suits 50
# Sofa cum bed 20
# Massager 19

# %%
print('Mean : ',d[dates[2]]['Count'].mean())
print('Median : ',d[dates[2]]['Count'].median())
# Out:
# Mean :  4.483870967741935
# Median :  2.0

# %%
## date 4

# %%
d[dates[3]]=d[dates[3]].sort_values(by='Count',ascending=False)
b=sns.barplot(x='Products',y='Count',data=d[dates[3]])
plt.gcf().set_size_inches(50,15)
b.axes.set_title(dates[3],fontsize=50)
b.set_xlabel('Products',fontsize=30)
b.set_ylabel('Count',fontsize=30)
b.set_yticklabels(b.get_yticks(), size=30)
b.set_xticklabels(b.get_xticks(), size=30)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '12'),
#  Text(0, 0, '13'),
#  Text(0, 0, '14'),
#  Text(0, 0, '15'),
#  Text(0, 0, '16'),
#  Text(0, 0, '17'),
#  Text(0, 0, '18'),
#  Text(0, 0, '19'),
#  Text(0, 0, '20'),
#  Text(0, 0, '21'),
#  Text(0, 0, '22'),
#  Text(0, 0, '23'),
#  Text(0, 0, '24'),
#  Text(0, 0, '25'),
#  Text(0, 0, '26'),
#  Text(0, 0, '27')]

# %%
print(d[dates[3]].iloc[0]['Products'],d[dates[3]].iloc[0]['Count'])
print(d[dates[3]].iloc[1]['Products'],d[dates[3]].iloc[1]['Count'])
print(d[dates[3]].iloc[2]['Products'],d[dates[3]].iloc[2]['Count'])
# Out:
# Suits 21
# Jamdani Saree 7
# Massager 7

# %%
print('Mean : ',d[dates[3]]['Count'].mean())
print('Median : ',d[dates[3]]['Count'].median())
# Out:
# Mean :  2.5714285714285716
# Median :  1.0

# %%
## date 5

# %%
d[dates[4]]=d[dates[4]].sort_values(by='Count',ascending=False)
b=sns.barplot(x='Products',y='Count',data=d[dates[4]])
plt.gcf().set_size_inches(50,15)
b.axes.set_title(dates[4],fontsize=50)
b.set_xlabel('Products',fontsize=30)
b.set_ylabel('Count',fontsize=30)
b.set_yticklabels(b.get_yticks(), size=30)
b.set_xticklabels(b.get_xticks(), size=30)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '12'),
#  Text(0, 0, '13'),
#  Text(0, 0, '14'),
#  Text(0, 0, '15'),
#  Text(0, 0, '16'),
#  Text(0, 0, '17'),
#  Text(0, 0, '18'),
#  Text(0, 0, '19'),
#  Text(0, 0, '20'),
#  Text(0, 0, '21'),
#  Text(0, 0, '22'),
#  Text(0, 0, '23'),
#  Text(0, 0, '24'),
#  Text(0, 0, '25'),
#  Text(0, 0, '26'),
#  Text(0, 0, '27'),
#  Text(0, 0, '28'),
#  Text(0, 0, '29'),
#  Text(0, 0, '30'),
#  Text(0, 0, '31'),
#  Text(0, 0, '32'),
#  Text(0, 0, '33'),
#  Text(0, 0, '34'),
#  Text(0, 0, '35'),
#  Text(0, 0, '36'),
#  Text(0, 0, '37'),
#  Text(0, 0, '38'),
#  Text(0, 0, '39'),
#  Text(0, 0, '40'),
#  Text(0, 0, '41'),
#  Text(0, 0, '42'),
#  Text(0, 0, '43')]

# %%
print(d[dates[4]].iloc[0]['Products'],d[dates[4]].iloc[0]['Count'])
print(d[dates[4]].iloc[1]['Products'],d[dates[4]].iloc[1]['Count'])
print(d[dates[4]].iloc[2]['Products'],d[dates[4]].iloc[2]['Count'])
# Out:
# Suits 29
# Jamdani Saree 9
# Garments 9

# %%
print('Mean : ',d[dates[4]]['Count'].mean())
print('Median : ',d[dates[4]]['Count'].median())
# Out:
# Mean :  2.840909090909091
# Median :  1.0

# %%
## date 6

# %%
d[dates[5]]=d[dates[5]].sort_values(by='Count',ascending=False)
b=sns.barplot(x='Products',y='Count',data=d[dates[5]])
plt.gcf().set_size_inches(50,15)
b.axes.set_title(dates[5],fontsize=50)
b.set_xlabel('Products',fontsize=30)
b.set_ylabel('Count',fontsize=30)
b.set_yticklabels(b.get_yticks(), size=30)
b.set_xticklabels(b.get_xticks(), size=30)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '12'),
#  Text(0, 0, '13'),
#  Text(0, 0, '14'),
#  Text(0, 0, '15'),
#  Text(0, 0, '16'),
#  Text(0, 0, '17'),
#  Text(0, 0, '18'),
#  Text(0, 0, '19'),
#  Text(0, 0, '20'),
#  Text(0, 0, '21'),
#  Text(0, 0, '22'),
#  Text(0, 0, '23'),
#  Text(0, 0, '24'),
#  Text(0, 0, '25'),
#  Text(0, 0, '26'),
#  Text(0, 0, '27'),
#  Text(0, 0, '28'),
#  Text(0, 0, '29'),
#  Text(0, 0, '30'),
#  Text(0, 0, '31'),
#  Text(0, 0, '32'),
#  Text(0, 0, '33'),
#  Text(0, 0, '34'),
#  Text(0, 0, '35'),
#  Text(0, 0, '36'),
#  Text(0, 0, '37'),
#  Text(0, 0, '38'),
#  Text(0, 0, '39'),
#  Text(0, 0, '40'),
#  Text(0, 0, '41'),
#  Text(0, 0, '42'),
#  Text(0, 0, '43')]

# %%
print(d[dates[5]].iloc[0]['Products'],d[dates[5]].iloc[0]['Count'])
print(d[dates[5]].iloc[1]['Products'],d[dates[5]].iloc[1]['Count'])
print(d[dates[5]].iloc[2]['Products'],d[dates[5]].iloc[2]['Count'])
# Out:
# Suits 31
# Garments 23
# Jamdani Saree 20

# %%
print('Mean : ',d[dates[5]]['Count'].mean())
print('Median : ',d[dates[5]]['Count'].median())
# Out:
# Mean :  3.590909090909091
# Median :  2.0

# %%
## date 7

# %%
d[dates[6]]=d[dates[6]].sort_values(by='Count',ascending=False)
b=sns.barplot(x='Products',y='Count',data=d[dates[6]])
plt.gcf().set_size_inches(50,15)
b.axes.set_title(dates[6],fontsize=50)
b.set_xlabel('Products',fontsize=30)
b.set_ylabel('Count',fontsize=30)
b.set_yticklabels(b.get_yticks(), size=30)
b.set_xticklabels(b.get_xticks(), size=30)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '12'),
#  Text(0, 0, '13'),
#  Text(0, 0, '14'),
#  Text(0, 0, '15'),
#  Text(0, 0, '16'),
#  Text(0, 0, '17'),
#  Text(0, 0, '18'),
#  Text(0, 0, '19'),
#  Text(0, 0, '20'),
#  Text(0, 0, '21'),
#  Text(0, 0, '22'),
#  Text(0, 0, '23'),
#  Text(0, 0, '24'),
#  Text(0, 0, '25'),
#  Text(0, 0, '26'),
#  Text(0, 0, '27'),
#  Text(0, 0, '28'),
#  Text(0, 0, '29'),
#  Text(0, 0, '30'),
#  Text(0, 0, '31'),
#  Text(0, 0, '32'),
#  Text(0, 0, '33'),
#  Text(0, 0, '34'),
#  Text(0, 0, '35'),
#  Text(0, 0, '36'),
#  Text(0, 0, '37'),
#  Text(0, 0, '38'),
#  Text(0, 0, '39'),
#  Text(0, 0, '40'),
#  Text(0, 0, '41'),
#  Text(0, 0, '42'),
#  Text(0, 0, '43'),
#  Text(0, 0, '44'),
#  Text(0, 0, '45'),
#  Text(0, 0, '46')]

# %%
print(d[dates[6]].iloc[0]['Products'],d[dates[6]].iloc[0]['Count'])
print(d[dates[6]].iloc[1]['Products'],d[dates[6]].iloc[1]['Count'])
print(d[dates[6]].iloc[2]['Products'],d[dates[6]].iloc[2]['Count'])
# Out:
# Garments 27
# Suits 13
# kurti 9

# %%
print('Mean : ',d[dates[6]]['Count'].mean())
print('Median : ',d[dates[6]]['Count'].median())
# Out:
# Mean :  2.9361702127659575
# Median :  1.0

# %%
## date 8

# %%
d[dates[7]]=d[dates[7]].sort_values(by='Count',ascending=False)
b=sns.barplot(x='Products',y='Count',data=d[dates[7]])
plt.gcf().set_size_inches(70,15)
b.axes.set_title(dates[7],fontsize=50)
b.set_xlabel('Products',fontsize=30)
b.set_ylabel('Count',fontsize=30)
b.set_yticklabels(b.get_yticks(), size=30)
b.set_xticklabels(b.get_xticks(), size=30)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '12'),
#  Text(0, 0, '13'),
#  Text(0, 0, '14'),
#  Text(0, 0, '15'),
#  Text(0, 0, '16'),
#  Text(0, 0, '17'),
#  Text(0, 0, '18'),
#  Text(0, 0, '19'),
#  Text(0, 0, '20'),
#  Text(0, 0, '21'),
#  Text(0, 0, '22'),
#  Text(0, 0, '23'),
#  Text(0, 0, '24'),
#  Text(0, 0, '25'),
#  Text(0, 0, '26'),
#  Text(0, 0, '27'),
#  Text(0, 0, '28'),
#  Text(0, 0, '29'),
#  Text(0, 0, '30'),
#  Text(0, 0, '31'),
#  Text(0, 0, '32'),
#  Text(0, 0, '33'),
#  Text(0, 0, '34'),
#  Text(0, 0, '35'),
#  Text(0, 0, '36'),
#  Text(0, 0, '37'),
#  Text(0, 0, '38'),
#  Text(0, 0, '39'),
#  Text(0, 0, '40'),
#  Text(0, 0, '41')]

# %%
print(d[dates[7]].iloc[0]['Products'],d[dates[7]].iloc[0]['Count'])
print(d[dates[7]].iloc[1]['Products'],d[dates[7]].iloc[1]['Count'])
print(d[dates[7]].iloc[2]['Products'],d[dates[7]].iloc[2]['Count'])
# Out:
# Suits 28
# Garments 20
# Jamdani Saree 11

# %%
print('Mean : ',d[dates[8]]['Count'].mean())
print('Median : ',d[dates[8]]['Count'].median())
# Out:
# Mean :  4.166666666666667
# Median :  1.5

# %%
## date 9

# %%
d[dates[8]]=d[dates[8]].sort_values(by='Count',ascending=False)
b=sns.barplot(x='Products',y='Count',data=d[dates[8]])
plt.gcf().set_size_inches(80,15)
b.axes.set_title(dates[8],fontsize=50)
b.set_xlabel('Products',fontsize=30)
b.set_ylabel('Count',fontsize=30)
b.set_yticklabels(b.get_yticks(), size=30)
b.set_xticklabels(b.get_xticks(), size=30)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '12'),
#  Text(0, 0, '13'),
#  Text(0, 0, '14'),
#  Text(0, 0, '15'),
#  Text(0, 0, '16'),
#  Text(0, 0, '17'),
#  Text(0, 0, '18'),
#  Text(0, 0, '19'),
#  Text(0, 0, '20'),
#  Text(0, 0, '21'),
#  Text(0, 0, '22'),
#  Text(0, 0, '23'),
#  Text(0, 0, '24'),
#  Text(0, 0, '25'),
#  Text(0, 0, '26'),
#  Text(0, 0, '27'),
#  Text(0, 0, '28'),
#  Text(0, 0, '29'),
#  Text(0, 0, '30'),
#  Text(0, 0, '31'),
#  Text(0, 0, '32'),
#  Text(0, 0, '33'),
#  Text(0, 0, '34'),
#  Text(0, 0, '35'),
#  Text(0, 0, '36'),
#  Text(0, 0, '37'),
#  Text(0, 0, '38'),
#  Text(0, 0, '39'),
#  Text(0, 0, '40'),
#  Text(0, 0, '41'),
#  Text(0, 0, '42'),
#  Text(0, 0, '43'),
#  Text(0, 0, '44'),
#  Text(0, 0, '45'),
#  Text(0, 0, '46'),
#  Text(0, 0, '47'),
# ...

# %%
print(d[dates[8]].iloc[0]['Products'],d[dates[8]].iloc[0]['Count'])
print(d[dates[8]].iloc[1]['Products'],d[dates[8]].iloc[1]['Count'])
print(d[dates[8]].iloc[2]['Products'],d[dates[8]].iloc[2]['Count'])
# Out:
# Garments 45
# Suits 28
# Jamdani Saree 21

# %%
print('Mean : ',d[dates[9]]['Count'].mean())
print('Median : ',d[dates[9]]['Count'].median())
# Out:
# Mean :  5.092307692307692
# Median :  2.0

# %%
## date 10

# %%
d[dates[9]]=d[dates[9]].sort_values(by='Count',ascending=False)
b=sns.barplot(x='Products',y='Count',data=d[dates[9]])
plt.gcf().set_size_inches(80,15)
b.axes.set_title(dates[9],fontsize=50)
b.set_xlabel('Products',fontsize=30)
b.set_ylabel('Count',fontsize=30)
b.set_yticklabels(b.get_yticks(), size=30)
b.set_xticklabels(b.get_xticks(), size=30)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '12'),
#  Text(0, 0, '13'),
#  Text(0, 0, '14'),
#  Text(0, 0, '15'),
#  Text(0, 0, '16'),
#  Text(0, 0, '17'),
#  Text(0, 0, '18'),
#  Text(0, 0, '19'),
#  Text(0, 0, '20'),
#  Text(0, 0, '21'),
#  Text(0, 0, '22'),
#  Text(0, 0, '23'),
#  Text(0, 0, '24'),
#  Text(0, 0, '25'),
#  Text(0, 0, '26'),
#  Text(0, 0, '27'),
#  Text(0, 0, '28'),
#  Text(0, 0, '29'),
#  Text(0, 0, '30'),
#  Text(0, 0, '31'),
#  Text(0, 0, '32'),
#  Text(0, 0, '33'),
#  Text(0, 0, '34'),
#  Text(0, 0, '35'),
#  Text(0, 0, '36'),
#  Text(0, 0, '37'),
#  Text(0, 0, '38'),
#  Text(0, 0, '39'),
#  Text(0, 0, '40'),
#  Text(0, 0, '41'),
#  Text(0, 0, '42'),
#  Text(0, 0, '43'),
#  Text(0, 0, '44'),
#  Text(0, 0, '45'),
#  Text(0, 0, '46'),
#  Text(0, 0, '47'),
# ...

# %%
print(d[dates[9]].iloc[0]['Products'],d[dates[9]].iloc[0]['Count'])
print(d[dates[9]].iloc[1]['Products'],d[dates[9]].iloc[1]['Count'])
print(d[dates[9]].iloc[2]['Products'],d[dates[9]].iloc[2]['Count'])`
# Out:
# Suits 56
# Garments 38
# Jamdani Saree 27

# %%
print('Mean : ',d[dates[9]]['Count'].mean())
print('Median : ',d[dates[9]]['Count'].median())
# Out:
# Mean :  5.092307692307692
# Median :  2.0

# %%
## date 11

# %%
d[dates[10]]=d[dates[10]].sort_values(by='Count',ascending=False)
b=sns.barplot(x='Products',y='Count',data=d[dates[10]])
plt.gcf().set_size_inches(50,15)
b.axes.set_title(dates[10],fontsize=50)
b.set_xlabel('Products',fontsize=30)
b.set_ylabel('Count',fontsize=30)
b.set_yticklabels(b.get_yticks(), size=30)
b.set_xticklabels(b.get_xticks(), size=30)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '12'),
#  Text(0, 0, '13'),
#  Text(0, 0, '14'),
#  Text(0, 0, '15'),
#  Text(0, 0, '16'),
#  Text(0, 0, '17'),
#  Text(0, 0, '18'),
#  Text(0, 0, '19'),
#  Text(0, 0, '20'),
#  Text(0, 0, '21'),
#  Text(0, 0, '22'),
#  Text(0, 0, '23'),
#  Text(0, 0, '24'),
#  Text(0, 0, '25'),
#  Text(0, 0, '26'),
#  Text(0, 0, '27'),
#  Text(0, 0, '28'),
#  Text(0, 0, '29'),
#  Text(0, 0, '30'),
#  Text(0, 0, '31'),
#  Text(0, 0, '32'),
#  Text(0, 0, '33'),
#  Text(0, 0, '34'),
#  Text(0, 0, '35'),
#  Text(0, 0, '36'),
#  Text(0, 0, '37'),
#  Text(0, 0, '38'),
#  Text(0, 0, '39'),
#  Text(0, 0, '40'),
#  Text(0, 0, '41'),
#  Text(0, 0, '42'),
#  Text(0, 0, '43'),
#  Text(0, 0, '44'),
#  Text(0, 0, '45'),
#  Text(0, 0, '46'),
#  Text(0, 0, '47'),
# ...

# %%
print(d[dates[10]].iloc[0]['Products'],d[dates[10]].iloc[0]['Count'])
print(d[dates[10]].iloc[1]['Products'],d[dates[10]].iloc[1]['Count'])
print(d[dates[10]].iloc[2]['Products'],d[dates[10]].iloc[2]['Count'])
# Out:
# Garments 56
# Suits 52
# Jamdani Saree 30

# %%
print('Mean : ',d[dates[10]]['Count'].mean())
print('Median : ',d[dates[10]]['Count'].median())
# Out:
# Mean :  5.405797101449275
# Median :  3.0

# %%
## date 12

# %%
d[dates[11]]=d[dates[11]].sort_values(by='Count',ascending=False)
b=sns.barplot(x='Products',y='Count',data=d[dates[11]])
plt.gcf().set_size_inches(50,15)
b.axes.set_title(dates[11],fontsize=50)
b.set_xlabel('Products',fontsize=30)
b.set_ylabel('Count',fontsize=30)
b.set_yticklabels(b.get_yticks(), size=30)
b.set_xticklabels(b.get_xticks(), size=30)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '12'),
#  Text(0, 0, '13'),
#  Text(0, 0, '14'),
#  Text(0, 0, '15'),
#  Text(0, 0, '16'),
#  Text(0, 0, '17'),
#  Text(0, 0, '18'),
#  Text(0, 0, '19'),
#  Text(0, 0, '20'),
#  Text(0, 0, '21'),
#  Text(0, 0, '22'),
#  Text(0, 0, '23'),
#  Text(0, 0, '24'),
#  Text(0, 0, '25'),
#  Text(0, 0, '26'),
#  Text(0, 0, '27'),
#  Text(0, 0, '28'),
#  Text(0, 0, '29'),
#  Text(0, 0, '30'),
#  Text(0, 0, '31'),
#  Text(0, 0, '32'),
#  Text(0, 0, '33'),
#  Text(0, 0, '34'),
#  Text(0, 0, '35'),
#  Text(0, 0, '36'),
#  Text(0, 0, '37'),
#  Text(0, 0, '38'),
#  Text(0, 0, '39'),
#  Text(0, 0, '40'),
#  Text(0, 0, '41'),
#  Text(0, 0, '42'),
#  Text(0, 0, '43')]

# %%
print(d[dates[11]].iloc[0]['Products'],d[dates[11]].iloc[0]['Count'])
print(d[dates[11]].iloc[1]['Products'],d[dates[11]].iloc[1]['Count'])
print(d[dates[11]].iloc[2]['Products'],d[dates[11]].iloc[2]['Count'])
# Out:
# Suits 39
# Garments 30
# Jamdani Saree 22

# %%
print('Mean : ',d[dates[11]]['Count'].mean())
print('Median : ',d[dates[11]]['Count'].median())
# Out:
# Mean :  4.704545454545454
# Median :  2.0

# %%
## date 13

# %%
d[dates[12]]=d[dates[12]].sort_values(by='Count',ascending=False)
b=sns.barplot(x='Products',y='Count',data=d[dates[12]])
plt.gcf().set_size_inches(80,15)
b.axes.set_title(dates[12],fontsize=50)
b.set_xlabel('Products',fontsize=30)
b.set_ylabel('Count',fontsize=30)
b.set_yticklabels(b.get_yticks(), size=30)
b.set_xticklabels(b.get_xticks(), size=30)
# Out:
# [Text(0, 0, '0'),
#  Text(0, 0, '1'),
#  Text(0, 0, '2'),
#  Text(0, 0, '3'),
#  Text(0, 0, '4'),
#  Text(0, 0, '5'),
#  Text(0, 0, '6'),
#  Text(0, 0, '7'),
#  Text(0, 0, '8'),
#  Text(0, 0, '9'),
#  Text(0, 0, '10'),
#  Text(0, 0, '11'),
#  Text(0, 0, '12'),
#  Text(0, 0, '13'),
#  Text(0, 0, '14'),
#  Text(0, 0, '15'),
#  Text(0, 0, '16'),
#  Text(0, 0, '17'),
#  Text(0, 0, '18'),
#  Text(0, 0, '19'),
#  Text(0, 0, '20'),
#  Text(0, 0, '21'),
#  Text(0, 0, '22'),
#  Text(0, 0, '23'),
#  Text(0, 0, '24'),
#  Text(0, 0, '25'),
#  Text(0, 0, '26'),
#  Text(0, 0, '27'),
#  Text(0, 0, '28'),
#  Text(0, 0, '29'),
#  Text(0, 0, '30'),
#  Text(0, 0, '31'),
#  Text(0, 0, '32'),
#  Text(0, 0, '33'),
#  Text(0, 0, '34'),
#  Text(0, 0, '35'),
#  Text(0, 0, '36'),
#  Text(0, 0, '37'),
#  Text(0, 0, '38'),
#  Text(0, 0, '39'),
#  Text(0, 0, '40'),
#  Text(0, 0, '41'),
#  Text(0, 0, '42'),
#  Text(0, 0, '43'),
#  Text(0, 0, '44'),
#  Text(0, 0, '45'),
#  Text(0, 0, '46'),
#  Text(0, 0, '47'),
# ...

# %%
print(d[dates[12]].iloc[0]['Products'],d[dates[12]].iloc[0]['Count'])
print(d[dates[12]].iloc[1]['Products'],d[dates[12]].iloc[1]['Count'])
print(d[dates[12]].iloc[2]['Products'],d[dates[12]].iloc[2]['Count'])
# Out:
# Garments 70
# Suits 21
# Cloths 20

# %%
print('Mean : ',d[dates[12]]['Count'].mean())
print('Median : ',d[dates[12]]['Count'].median())
# Out:
# Mean :  4.383720930232558
# Median :  2.0

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Findings (On basis of sale counts (not considering the amount)) :

# %% [markdown]
# <div>
#  <ol>
#     <li>We should consider the top 3 products for each date that  have performed well on basis of sales count . </li>
#     <li>After seeing the mean and median for each date , I can say that data is not skewed to on end completely (i.e on extreme low sales or extremely high sales) </li>
#     <li>So, considering the top 3 would be more better than declaring only one top performing product for each date. </li>
#  </ol>
#
# </div>
