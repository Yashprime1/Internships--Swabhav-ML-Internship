# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sklearn
from sklearn import datasets
from sklearn.model_selection import train_test_split

# %%
california = datasets.fetch_california_housing()

# %%
print(california.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 20640
#
#     :Number of Attributes: 8 numeric, predictive attributes and the target
#
#     :Attribute Information:
#         - MedInc        median income in block
#         - HouseAge      median house age in block
#         - AveRooms      average number of rooms
#         - AveBedrms     average number of bedrooms
#         - Population    block population
#         - AveOccup      average house occupancy
#         - Latitude      house block latitude
#         - Longitude     house block longitude
#
#     :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# http://lib.stat.cmu.edu/datasets/
#
# The target variable is the median house value for California districts.
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# ...

# %%
type(california.feature_names)
# Out:
# list

# %%
type(california.target)
# Out:
# numpy.ndarray

# %%
california.target
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
samples=california.data.shape
samples
# Out:
# (20640, 8)

# %%
#analysis

# %%
print(california.data[:,0])
# Out:
# [8.3252 8.3014 7.2574 ... 1.7    1.8672 2.3886]

# %%
sns.distplot(california.data[:,0])

# %%
sns.distplot(california.data[:,1])

# %%
sns.distplot(california.data[:,2])

# %%
sns.distplot(california.data[:,3])

# %%
sns.distplot(california.data[:,4])

# %%
sns.distplot(california.data[:,5])

# %%
sns.distplot(california.data[:,6])

# %%
sns.distplot(california.data[:,7])

# %%
# normalizing

# %%
sns.distplot(np.log(california.data[:,0]))

# %%
sns.distplot(np.log(california.data[:,1]))

# %%
sns.distplot(np.log(california.data[:,2]))

# %%
sns.distplot(np.log(california.data[:,3]))

# %%
sns.distplot(np.log(california.data[:,4]))

# %%
sns.distplot(np.log(california.data[:,5]))

# %%
sns.distplot(np.log(california.data[:,6]))

# %%
california.data[:,0]=np.log(california.data[:,0])

# %%
california.data[:,2]=np.log(california.data[:,2])
california.data[:,3]=np.log(california.data[:,3])
california.data[:,4]=np.log(california.data[:,4])
california.data[:,5]=np.log(california.data[:,5])

# %%
california.data
# Out:
# array([[   2.11928706,   41.        ,    1.94364   , ...,    0.93826964,
#           37.88      , -122.23      ],
#        [   2.11642418,   21.        ,    1.83068159, ...,    0.74661298,
#           37.86      , -122.22      ],
#        [   1.98202164,   52.        ,    2.11482505, ...,    1.03042619,
#           37.85      , -122.24      ],
#        ...,
#        [   0.53062825,   17.        ,    1.64972397, ...,    0.84399316,
#           39.43      , -121.22      ],
#        [   0.62443998,   18.        ,    1.67325984, ...,    0.7529287 ,
#           39.43      , -121.32      ],
#        [   0.87070742,   16.        ,    1.65912615, ...,    0.96202141,
#           39.37      , -121.24      ]])

# %%
from sklearn.model_selection import train_test_split
train_inputs, test_inputs, train_labels, test_labels = train_test_split(california.data, california.target, test_size = 0.20)

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X=train_inputs, y=train_labels)
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)
train_pred = lm.predict(train_inputs)
test_pred=lm.predict(test_inputs)

# %%
lm.score(train_inputs,train_labels)
# Out:
# 0.6077274754131587

# %%
lm.score(test_inputs,test_labels)
# Out:
# 0.606577558491751

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(test_labels, lm.predict(test_inputs))
# Out:
# 0.535282512734111

# %%
mean_squared_error(test_labels, test_pred)
# Out:
# 0.535282512734111
